# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/anuragpanchal/Documents/MachineLearning/KMeans Quiz/Live.csv')

# %%
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
len(df['status_id'].unique())
# Out:
# 6997

# %%
df['status_type'].value_counts()
# Out:
# status_type
# photo     4288
# video     2334
# status     365
# link        63
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df['status_published']= pd.to_datetime(df['status_published'])

# %%
df[(df['status_type']=='photo') & (df['status_published']=='4/19/2018 22:26:00')]
# Out:
#                             status_id status_type    status_published  \
# 4592  725980084255106_850951205091326       photo 2018-04-19 22:26:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 4592            383             5           6        379          2         2
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# 4592          0         0           0      NaN      NaN      NaN      NaN

# %%
df[(df['status_type']=='video') & (df['status_published']=='7/15/2017 10:52:00')]
# Out:
#                               status_id status_type    status_published  \
# 6977  1050855161656896_1339706342771775       video 2017-07-15 10:52:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 6977            253          4432         167        209         29         5
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# 6977          5         5           0      NaN      NaN      NaN      NaN

# %%
df.tail()
# Out:
#                               status_id status_type    status_published  \
# 7045  1050855161656896_1061863470556065       photo 2016-09-24 02:58:00
# 7046  1050855161656896_1061334757275603       photo 2016-09-23 11:19:00
# 7047  1050855161656896_1060126464063099       photo 2016-09-21 23:03:00
# 7048  1050855161656896_1058663487542730       photo 2016-09-20 00:43:00
# 7049  1050855161656896_1050858841656528       photo 2016-09-10 10:30:00
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
# ...

# %%
df.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.drop(columns=['Column1','Column2','Column4','Column3','status_id','status_published'],inplace=True)

# %%
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %%
le = LabelEncoder()
df['status_type'] = le.fit_transform(df['status_type'])

# %%
df_scaled = MinMaxScaler().fit_transform(df)

# %%
df_scaled = pd.DataFrame(df_scaled,columns=df.columns)

# %%
df_scaled
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0        1.000000       0.112314      0.024393    0.076519   0.091720
# 1        0.333333       0.031847      0.000000    0.000000   0.031847
# 2        1.000000       0.048195      0.011243    0.016647   0.043312
# 3        0.333333       0.023567      0.000000    0.000000   0.023567
# 4        0.333333       0.045223      0.000000    0.000000   0.043312
# ...           ...            ...           ...         ...        ...
# 7045     0.333333       0.018896      0.000000    0.000000   0.018896
# 7046     0.333333       0.003397      0.000000    0.000000   0.002972
# 7047     0.333333       0.000425      0.000000    0.000000   0.000212
# 7048     0.333333       0.074522      0.000572    0.006425   0.074098
# 7049     0.333333       0.003609      0.000000    0.000000   0.003609
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0      0.140030  0.010791   0.006369  0.019608         0.0
# ...

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=2,random_state=42)

# %%
model.fit(df_scaled)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
model.inertia_
# Out:
# 240.06686397262814
